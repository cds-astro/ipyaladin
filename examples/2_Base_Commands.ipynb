# %% [markdown]
# # Aladin commands

# %%
from ipyaladin import Aladin

# %% [markdown]
# A list of all available commands can be displayed as such.

# %%
print(dir(Aladin))
# Out:
# ['__annotations__', '__class__', '__del__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_active_widgets', '_add_notifiers', '_all_trait_default_generators', '_call_widget_constructed', '_comm_changed', '_compare', '_control_comm', '_default_keys', '_default_options', '_descriptors', '_dom_classes', '_gen_repr_from_keys', '_get_embed_state', '_get_trait_default_generator', '_handle_control_comm_msg', '_handle_custom_msg', '_handle_msg', '_holding_sync', '_instance_inits', '_is_numpy', '_lock_property', '_log_default', '_model_module', '_model_module_version', '_model_name', '_msg_callbacks', '_notify_observers', '_notify_trait', '_property_lock', '_register_validator', '_remove_notifiers', '_repr_keys', '_repr_mimebundle_', '_send', '_should_send_property', '_states_to_send', '_static_immutable_initial_values', '_trait_default_generators', '_trait_from_json', '_trait_to_json', '_traits', '_view_count', '_view_module', '_view_module_version', '_view_name', '_widget_construction_callback', '_widget_types', 'add_catalog_from_URL', 'add_class', 'add_listener', 'add_moc_from_URL', 'add_moc_from_dict', 'add_overlay_from_stcs', 'add_table', 'add_traits', 'allow_full_zoomout', 'blur', 'class_own_trait_events', 'class_own_traits', 'class_trait_names', 'class_traits', 'close', 'close_all', 'color_map_flag', 'color_map_name', 'comm', 'coo_frame', 'cross_validation_lock', 'focus', 'fov', 'full_screen', 'get_JPEG_thumbnail', 'get_manager_state', 'get_state', 'get_view_spec', 'handle_aladin_event', 'handle_comm_opened', 'handle_control_comm_opened', 'has_trait', 'height', 'hold_sync', 'hold_trait_notifications', 'keys', 'last_prompt_length', 'layout', 'listener_callback_click', 'listener_callback_source_click', 'listener_callback_source_hover', 'listener_flag', 'listener_type', 'log', 'moc_URL', 'moc_dict', 'moc_from_URL_flag', 'moc_from_dict_flag', 'moc_options', 'model_id', 'notify_change', 'observe', 'on_msg', 'on_trait_change', 'on_widget_constructed', 'open', 'options', 'overlay_from_stcs_flag', 'overlay_options', 'overlay_survey', 'overlay_survey_opacity', 'rectangular_selection', 'rectangular_selection_callback', 'rectangular_selection_flag', 'remove_class', 'reticle_color', 'reticle_size', 'send', 'send_state', 'set_color_map', 'set_state', 'set_trait', 'setup_instance', 'show_catalog', 'show_context_menu', 'show_coo_grid', 'show_frame', 'show_fullscreen_control', 'show_goto_control', 'show_layers_control', 'show_reticle', 'show_share_control', 'show_simbad_pointer_control', 'show_zoom_control', 'stc_string', 'survey', 'tabbable', 'table_columns', 'table_flag', 'table_keys', 'target', 'thumbnail_flag', 'tooltip', 'trait_defaults', 'trait_events', 'trait_has_value', 'trait_metadata', 'trait_names', 'trait_values', 'traits', 'unobserve', 'unobserve_all', 'update_WCS', 'update_wcs_flag', 'votable_URL', 'votable_from_URL_flag', 'votable_options', 'wcs', 'widget_types', 'widgets']

# %% [markdown]
# A few of them are illustrated in the next cells. Let's first, create the widget with a few initial parameters:

# %%
aladin = Aladin(fov=20, reticle_size=64, reticle_color="#ff89ff")
aladin
# Out:
# Aladin(fov=20.0, options=['allow_full_zoomout', 'coo_frame', 'fov', 'full_screen', 'log', 'overlay_survey', 'o…

# %% [markdown]
# They can also be modified in the next cells with an interactive effect on the generated view.

# %%
aladin.target = "sgr a*"

# %%
aladin.fov = 2

# %%
aladin.overlay_survey = "P/allWISE/color"
aladin.overlay_survey_opacity = 0.5

# %%
aladin.coo_frame = "galactic"

# %%
aladin.update_WCS()

# %%
aladin.wcs
# Out:
# {'NAXIS': 2,
#  'NAXIS1': 1863,
#  'NAXIS2': 400,
#  'RADECSYS': 'ICRS',
#  'CRPIX1': 931.5,
#  'CRPIX2': 200,
#  'CRVAL1': 266.416816625,
#  'CRVAL2': -29.007824971999984,
#  'CTYPE1': 'RA---SIN',
#  'CTYPE2': 'DEC--SIN',
#  'CD1_1': 0.0010735373054213634,
#  'CD1_2': 0,
#  'CD2_1': 0,
#  'CD2_2': 0.0010735373054213634}
